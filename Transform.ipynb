# %%
import pandas as pd
import datetime as dt

# %%
# Files to Load
jan_2022 = "data/jc-202201-citibike-tripdata.csv"
jul_2022 = "data/jc-202207-citibike-tripdata.csv"

df_jan_2022 = pd.read_csv(jan_2022, encoding="ISO-8859-1")
df_jul_2022 = pd.read_csv(jul_2022, encoding="ISO-8859-1")

# %%
df_jan_2022.shape
# Out:
# (26762, 13)

# %%
df_jan_2022.dropna()
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      CA5837152804D4B5  electric_bike  2022-01-26 18:50:39
# 1      BA06A5E45B6601D2   classic_bike  2022-01-28 13:14:07
# 2      7B6827D7B9508D93   classic_bike  2022-01-10 19:55:13
# 3      6E5864EA6FCEC90D  electric_bike  2022-01-26 07:54:57
# 4      E24954255BBDE32D  electric_bike  2022-01-13 18:44:46
# ...                 ...            ...                  ...
# 26757  439B3B4ADB37F46F  electric_bike  2022-01-03 16:07:27
# 26758  11C0F2F85CBF7623  electric_bike  2022-01-22 20:02:58
# 26759  E77502BB6C6A7ADD   classic_bike  2022-01-26 12:35:21
# 26760  75C57C18EE9980EA   classic_bike  2022-01-28 12:56:34
# 26761  2EC5621EF3DCB2FA   classic_bike  2022-01-31 12:45:16
#
#                   ended_at    start_station_name start_station_id  \
# 0      2022-01-26 18:51:53  12 St & Sinatra Dr N            HB201
# 1      2022-01-28 13:20:23      Essex Light Rail            JC038
# ...

# %%
df_jan_2022.drop_duplicates()
# Out:
# (26762, 13)

# %%
df_jul_2022.dropna()
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       89CDCE3224502904   classic_bike  2022-07-21 18:19:45
# 1       3E6E50F51BD4CBD9  electric_bike  2022-07-21 17:50:57
# 2       8A9058FAA9115562  electric_bike  2022-07-23 11:51:55
# 3       C566A187663748AE   classic_bike  2022-07-30 20:34:40
# 4       7E754D57276BE57E   classic_bike  2022-07-14 18:42:34
# ...                  ...            ...                  ...
# 108497  724215864AE00DDE   classic_bike  2022-07-10 15:03:06
# 108498  47844D96219AEC80   classic_bike  2022-07-06 11:58:42
# 108499  A5DAD9319B4394A8  electric_bike  2022-07-20 16:10:54
# 108500  1438A3D941DD3174   classic_bike  2022-07-15 16:17:36
# 108501  D72C8CA7D49C30AB  electric_bike  2022-07-18 21:24:51
#
#                    ended_at                          start_station_name  \
# 0       2022-07-21 18:28:21                          Marshall St & 2 St
# 1       2022-07-21 17:59:17                          Marshall St & 2 St
# ...

# %%
df_jul_2022.drop_duplicates()

# %%
comparison_df = df_jan_2022.append(df_jul_2022, sort=False)
# Out:
# C:\Users\simon\AppData\Local\Temp\ipykernel_1760\415273684.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = df_jan_2022.append(df_jul_2022, sort=False)

# %%
comparison_df.to_csv("data/Jan-and-Jul2022.csv", index=False, header=True)
